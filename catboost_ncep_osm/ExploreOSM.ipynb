# %%
import gzip
import os
import sys

import gdal
import geopandas
import numpy as np
import ogr
import pandas as pd
from shapely import wkb
from collections import defaultdict

from tqdm import tqdm

DATA_PATH = '../data'

# %%
# %%time

def build_osm_stats(osm_file_name, limit=None):
    gdal.SetConfigOption('OGR_INTERLEAVED_READING', 'YES')
    osm = ogr.Open(osm_file_name)
    fields = defaultdict(lambda:defaultdict(int))
    layers={}
    print("Total layers: ",osm.GetLayerCount())
    for i in range(osm.GetLayerCount()):
        L=osm.GetLayer(i)
        L.ResetReading()
        print("Layer %i: %s"%(i+1,L.GetDescription()))
        cnt=0
        for feat in L:
            cnt += 1
            if cnt % 100000==0:
                print (cnt)
            for k,v in feat.items().items():
                if len(fields[k])>1000:
                    fields[k]['___others__']+=1
                else:
                    fields[k][v]+=1
            if limit is not None and cnt>=limit:
                break
        layers[i]={'index':i,'name':L.GetDescription(),'size':cnt}
    return layers, {k:{kk:vv for kk,vv in v.items()} for k,v in fields.items()}


try:
    with open(os.path.join(DATA_PATH,'osm_stats.pickle'),'rb') as f:
        layers, fields = pickle.load(f)
except:
    layers, fields = build_osm_stats(os.path.join(DATA_PATH,'russia-latest.osm.pbf'))
    with open(os.path.join(DATA_PATH,'osm_stats.pickle'),'wb') as f:
        pickle.dump((layers,fields),f)
# Out:
# Total layers:  5
# Layer 1: points
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# Layer 2: lines
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# 4700000
# 4800000
# 4900000
# 5000000
# 5100000
# 5200000
# 5300000
# 5400000
# 5500000
# 5600000
# 5700000
# 5800000
# 5900000
# 6000000
# 6100000
# 6200000
# 6300000
# 6400000
# 6500000
# 6600000
# 6700000
# 6800000
# 6900000
# 7000000
# 7100000
# 7200000
# 7300000
# 7400000
# 7500000
# 7600000
# 7700000
# 7800000
# 7900000
# 8000000
# 8100000
# 8200000
# 8300000
# 8400000
# 8500000
# 8600000
# 8700000
# 8800000
# Layer 3: multilinestrings
# Layer 4: multipolygons
# Layer 5: other_relations
# CPU times: user 25min 19s, sys: 49.1 s, total: 26min 8s
# Wall time: 28min 28s

# %%
for k in sorted(fields):
    print("%10s  %i"%(k,len(fields[k])))
    for kk in list(fields[k].keys())[:20]:
        print("\t\t%s"%kk)
    if len(fields[k])>20:
        print("\t\t...")
# Out:
#    address  8
# 		None
# 		Saatse küla, Värska vald, 64037 Põlva maakond
# 		Pikk 40, Värska, 64001 Põlvamaa
# 		Peterburi mnt 2, 20308 Narva, Ida-Virumaa
# 		Мичуринский пр-т, д. 20, к. 1 (Олимпийская деревня)
# 		ул.Комсомольская 10
# 		Город Омск, пр. Карла Маркса, 41/1
# 		Молочница
# admin_level  9
# 		None
# 		4
# 		6
# 		5
# 		8
# 		9
# 		7
# 		3
# 		10
#  aerialway  16
# 		None
# 		chair_lift
# 		platter
# 		drag_lift
# 		t-bar
# 		cable_car
# 		construction
# 		gondola
# 		j-bar
# 		rope_tow
# 		goods
# 		zip_line
# 		magic_carpet
# 		mixed_lift
# 		yes
# 		no
#    aeroway  2
# 		None
# 		aerodrome
#    amenity  41
# 		None
# 		school
# 		hospital
# 		college
# 		library
# 		public_building
# 		university
# 		clinic
# 		townhall
# 		theatre
# 		police
# 		stadiu
# 		community_centre
# 		arts_centre
# 		embassy
# 		cafe
# 		dentist
# 		parking
# 		kindergarten
# 		prison
# 		...
#    barrier  147
# 		None
# 		toll_booth
# 		lift_gate
# 		border_control
# 		gate
# 		block
# 		yes
# 		entrance
# 		bollard
# 		cycle_barrier
# 		cattle_grid
# 		height_restrictor
# 		chain
# 		border_crossing
# 		swing_gate
# 		sally_port
# 		hampshire_gate
# 		turnstile
# 		stile
# 		jersey_barrier
# 		...
#   boundary  4
# 		None
# 		administrative
# 		national_park
# 		protected_area
#   building  37
# 		None
# 		school
# 		yes
# 		commercial
# 		apartments
# 		residential
# 		public
# 		university
# 		stadium
# 		hospital
# 		office
# 		college
# 		kindergarten
# 		clinic
# 		hotel
# 		industrial
# 		education
# 		garages
# 		policlinic
# 		civic
# 		...
#      craft  1
# 		None
# geological  2
# 		None
# 		volcanic_lava_field
#    highway  104
# 		None
# 		passing_place
# 		traffic_signals
# 		milestone
# 		crossing
# 		give_way
# 		speed_camera
# 		bus_stop
# 		motorway_junction
# 		stop
# 		mini_roundabout
# 		toll_gantry
# 		turning_circle
# 		equal_roads
# 		street_lamp
# 		traffic_sign
# 		steps
# 		turning_loop
# 		fake_speed_camera
# 		emergency_access_point
# 		...
#   historic  11
# 		None
# 		palace
# 		castle
# 		meteor_crater
# 		memorial
# 		building
# 		yes
# 		monument
# 		ruins
# 		manor
# 		church
#      is_in  264
# 		None
# 		Ida-Viru, Estonia, EU
# 		Мурманская область
# 		Murmansk Oblast, Russia
# 		Новгородская область,Россия
# 		Россия
# 		Кемеровская область, Russia
# 		Rostov Oblast, Russia
# 		Finland
# 		gmina Banie Mazurskie, powiat gołdapski, województwo warmińsko-mazurskie, Poland
# 		Северная Осетия, Россия
# 		Komi Republic, Russia
# 		Kaliningrad, Northwest, Russia
# 		Калужская область
# 		Ярославская область
# 		Московская область
# 		Тверская область
# 		Aleutians West (CA),Alaska,Alaska,AK,USA
# 		Томск
# 		Томский район Томской области
# 		...
#  land_area  2
# 		None
# 		administrative
#    landuse  30
# 		None
# 		residential
# 		forest
# 		reservoir
# 		grass
# 		meadow
# 		peat_cutting
# 		allotments
# 		farmland
# 		construction
# 		quarry
# 		village_green
# 		industrial
# 		recreation_ground
# 		landfill
# 		cemetery
# 		national_reserve
# 		orchard
# 		farmyard
# 		railway
# 		...
#    leisure  16
# 		park
# 		None
# 		track
# 		nature_reserve
# 		stadium
# 		golf_course
# 		sports_centre
# 		pitch
# 		water_park
# 		playground
# 		sauna
# 		dog_park
# 		garden
# 		horse_riding
# 		common
# 		ice_rink
#   man_made  247
# 		survey_point
# 		None
# 		surveillance
# 		tower
# 		checkpoint
# 		obelisk
# 		crane
# 		works
# 		water_tower
# 		pier
# 		wastewater_plant
# 		lighthouse
# 		mast
# 		windmill
# 		water_well
# 		cairn
# 		port
# 		water_works
# 		chimney
# 		adit
# 		...
#   military  6
# 		None
# 		office
# 		bunker
# 		checkpoint
# 		headquarters
# 		registration_and_enlistment_office
#       name  1002
# 		Пулковский Меридиан
# 		Новосибирск
# 		Десяточка
# 		None
# 		Биржевая площадь
# 		Грибное
# 		Подгорье
# 		Башмаки неизвестного дачника (2009)
# 		Первомайское
# 		Симагино
# 		Передвижной комплекс
# 		Городец
# 		Мурманск
# 		Синявино
# 		Радар
# 		Новгородка
# 		Лопатово
# 		Магнитогорская улица
# 		Половина
# 		Мурмаши
# 		...
#    natural  14
# 		wood
# 		None
# 		water
# 		wetland
# 		scrub
# 		grassland
# 		heath
# 		fell
# 		spit
# 		sand
# 		beach
# 		bay
# 		lava
# 		mud
#     office  10
# 		None
# 		research
# 		government
# 		diplomatic
# 		news_agency
# 		administrative
# 		telecommunication
# 		educational_institution
# 		lawyer
# 		yes
#     osm_id  1002
# 		2
# 		54
# 		1000
# 		124330
# 		219812
# 		219816
# 		219818
# 		219819
# 		223552
# 		223587
# 		223589
# 		223609
# 		223612
# 		223628
# 		223641
# 		223647
# 		223677
# 		223683
# 		223697
# 		223698
# 		...
# osm_way_id  1
# 		None
# other_tags  1002
# 		"historic"=>"memorial","image"=>"https://upload.wikimedia.org/wikipedia/commons/d/d3/Pulkovo_meridian_zero-point.jpg","wikidata"=>"Q4383612","wikipedia"=>"ru:Пулковский меридиан"
# 		"addr:country"=>"RU","addr:region"=>"Новосибирская область","admin_level"=>"3","is_in:country"=>"Russia","name:ar"=>"نوفوسيبيرسك","name:be"=>"Новасібірск","name:ca"=>"Novossibirsk","name:cs"=>"Novosibirsk","name:da"=>"Novosibirsk","name:de"=>"Nowosibirsk","name:en"=>"Novosibirsk","name:es"=>"Novosibirsk","name:et"=>"Novosibirsk","name:fi"=>"Novosibirsk","name:fr"=>"Novossibirsk","name:he"=>"נובוסיבירסק","name:hi"=>"नोवोसिबिर्स्क","name:hr"=>"Novosibirsk","name:ja"=>"ノヴォシビルスク","name:kn"=>"ನೋವೋಸಿಬಿರ್ಸ್ಕ್","name:ko"=>"노보시비르스크","name:lt"=>"Novosibirskas","name:lv"=>"Novosibirska","name:oc"=>"Novosibirsk","name:pl"=>"Nowosybirsk","name:pt"=>"Novosibirsk","name:ro"=>"Novosibirsk","name:ru"=>"Новосибирск","name:sk"=>"Novosibirsk","name:sl"=>"Novosibirsk","name:uk"=>"Новосибірськ","official_status"=>"ru:город","old_name"=>"Ново-Николаевск","old_name:en"=>"Novo-Nikolayevsk","old_name:ru"=>"Ново-Николаевск","population"=>"1618039","population:date"=>"2019-01-01","source:name:oc"=>"Lo Congrès","wikidata"=>"Q883","wikipedia"=>"ru:Новосибирск"
# 		"comment"=>"ООО \"АСП-ГРУПП\", ИНН 7735108290, до 22:45 c 2014-05-23","opening_hours"=>"08:30-22:45","shop"=>"supermarket"
# 		None
# 		"bus"=>"yes","name:ru"=>"Биржевая площадь","trolleybus"=>"yes","public_transport"=>"stop_position"
# 		"distance"=>"2 km"
# 		"distance"=>"1 km"
# 		"amenity"=>"ferry_terminal"
# 		"distance"=>"144 km"
# 		"check_date"=>"2013-05-14","distance"=>"81 km","pk:backward"=>"128 km"
# 		"check_date"=>"2013-05-14","distance"=>"82 km","pk:backward"=>"127 km"
# 		"crossing"=>"uncontrolled"
# 		"check_date"=>"2013-05-14","distance"=>"88 km","pk:backward"=>"121 km"
# 		"check_date"=>"2013-05-14","distance"=>"89 km","pk:backward"=>"120 km"
# 		"check_date"=>"2013-05-14","distance"=>"115 km","pk:backward"=>"94 km"
# 		"check_date"=>"2013-05-14","distance"=>"125 km","pk:backward"=>"84 km"
# 		"access"=>"permissive"
# 		"crossing"=>"traffic_signals"
# 		"check_date"=>"2013-05-21","distance"=>"193 km","pk:backward"=>"16 km"
# 		"public_transport"=>"stop_position"
# 		...
#      place  35
# 		None
# 		city
# 		town
# 		village
# 		neighbourhood
# 		hamlet
# 		locality
# 		continent
# 		suburb
# 		isolated_dwelling
# 		allotments
# 		island
# 		region
# 		sea
# 		county
# 		mountain_range
# 		peninsula
# 		quarter
# 		islet
# 		country
# 		...
#        ref  1002
# 		None
# 		7;11;42;100;128;152
# 		8;14
# 		20
# 		15/50
# 		1/80
# 		747003
# 		106
# 		113
# 		108-109.043
# 		106-001.007
# 		113-107.002
# 		106-001.006
# 		106-001.009
# 		52B
# 		45
# 		62
# 		60А
# 		0;1A
# 		018/019
# 		...
#       shop  9
# 		None
# 		mall
# 		convenience
# 		department_store
# 		supermarket
# 		doityourself
# 		car_repair
# 		ticket
# 		furniture
#      sport  15
# 		None
# 		athletics
# 		shooting
# 		horse_racing
# 		soccer
# 		multi
# 		basketball
# 		volleyball
# 		baseball
# 		running
# 		motocross
# 		tennis
# 		equestrian
# 		karting
# 		skateboard
#    tourism  8
# 		None
# 		attraction
# 		hotel
# 		museum
# 		yes
# 		chalet
# 		theme_park
# 		hostel
#       type  37
# 		route
# 		multipolygon
# 		boundary
# 		restriction
# 		associatedStreet
# 		dual_carriageway
# 		street
# 		collection
# 		waterway
# 		bridge
# 		public_transport
# 		operator
# 		watershed
# 		rail
# 		building
# 		junction
# 		restriction:hgv
# 		destination_sign
# 		None
# 		loc_route
# 		...
#   waterway  56
# 		None
# 		riverbank
# 		ditch
# 		river
# 		canal
# 		stream
# 		weir
# 		dam
# 		drain
# 		dock
# 		drystream
# 		lock_gate
# 		undefined
# 		collector
# 		boatyard
# 		rapids
# 		dum
# 		derelict_canal
# 		wadi
# 		riverbank;river
# 		...
#    z_order  83
# 		3
# 		0
# 		4
# 		7
# 		6
# 		8
# 		5
# 		28
# 		17
# 		-4
# 		9
# 		16
# 		24
# 		29
# 		27
# 		25
# 		20
# 		18
# 		23
# 		26
# 		...
